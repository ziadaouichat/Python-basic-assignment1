# %% [markdown]
# ### Assignment_1 Solution

# %% [markdown]
# ### Q1:
# #### In the below elements which of them are values or an expression? eg:values can be
# #### integer or string and expressions will be mathematical operators.

# %% [markdown]
# ### S1:

# %% [markdown]
# #### * : Expression
# #### 'hello' : Values
# #### -87.8 : Values
# #### - : Expression
# #### / : Expression
# #### + : Expression
# #### 6 : Values

# %% [markdown]
# ### Q2:

# %% [markdown]
# ### What is the difference between string and variable?

# %% [markdown]
# ### S2:

# %% [markdown]
# #### String (' '," "): are a type of data where data is in single or double quotation
# #### Variable : are containers for storing the data values.

# %% [markdown]
# ### Q3:

# %% [markdown]
# ### Describe three different data types.

# %% [markdown]
# ### S3:

# %% [markdown]
# #### Integers : Whole Numbers
# #### Floats : Decimal Numbers
# #### Booleans : True or False values that means yes/No
# #### Lists : A collection of data between [ ]

# %% [markdown]
# ### Q4:

# %% [markdown]
# #### What is an expression made up of? What do all expressions do?

# %% [markdown]
# ### S4:

# %% [markdown]
# #### a):Expression is a combination of values , variables, operators and call to fntions.
# #### b):Expression need to be evaluated by the interpreter in order to displays the results.

# %% [markdown]
# ### Q5:

# %% [markdown]
# #### This assignment statements, like spam = 10. What is the difference between an
# #### expression and a statement?

# %% [markdown]
# ### S5:

# %% [markdown]
# #### Statement :like spam=10 means we create new variables called spam and give it a value of 10
# #### so when we enter the assignment statement spam =10 only the prompt is retrned , there is no value.
# #### in other hand when we excute the print function we will get the vale 10 of the variable spam

# %% [markdown]
# ### Q6:

# %% [markdown]
# #### After running the following code, what does the variable bacon contain?
# #### bacon = 22
# #### bacon + 1

# %% [markdown]
# ### S6:

# %% [markdown]
# ### 23

# %% [markdown]
# ### Q7:

# %% [markdown]
# #### What should the values of the following two terms be?
# #### 'spam'+'spamspam'
# #### 'spam' * 3

# %% [markdown]
# ### S7:

# %% [markdown]
# ### 'spamspamspam'

# %% [markdown]
# ### Q8:

# %% [markdown]
# ### Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# ### S8:

# %% [markdown]
# ### Variable name cannot begin with a number

# %% [markdown]
# ### Q9:

# %% [markdown]
# ### What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ### S9:

# %% [markdown]
# ### int() , float() , str() .

# %% [markdown]
# ### Q10:

# %% [markdown]
# ### Why does this expression cause an error? How can you fix it?
# #### 'I have eaten'+ 99 +'burritos'

# %% [markdown]
# ### S10:

# %% [markdown]
#  #### can only concatenate str (not "int") to str
